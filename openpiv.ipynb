# %%
# !pip install openpiv
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 44.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.0/297.0 KB 13.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 KB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 55.5 MB/s eta 0:00:00:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.2/181.2 KB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 60.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 KB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 KB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 72.0 MB/s eta 0:00:00:00:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.6/195.6 KB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 40.9 MB/s eta 0:00:00:00:01
# ...

# %%
from openpiv.piv import simple_piv

# %%
import imageio.v2 as imageio
a = imageio.imread('https://raw.githubusercontent.com/OpenPIV/openpiv-python-gpu/master/openpiv/examples/test1/exp1_001_a.bmp')
b = imageio.imread('https://raw.githubusercontent.com/OpenPIV/openpiv-python-gpu/master/openpiv/examples/test1/exp1_001_b.bmp')

# %%
simple_piv(a,b)
# Out:
# (array([[ 23.,  39.,  55.,  71.,  87., 103., 119., 135., 151., 167., 183.,
#          199., 215., 231., 247., 263., 279., 295., 311., 327., 343., 359.,
#          375., 391., 407., 423., 439., 455., 471., 487.],
#         [ 23.,  39.,  55.,  71.,  87., 103., 119., 135., 151., 167., 183.,
#          199., 215., 231., 247., 263., 279., 295., 311., 327., 343., 359.,
#          375., 391., 407., 423., 439., 455., 471., 487.],
#         [ 23.,  39.,  55.,  71.,  87., 103., 119., 135., 151., 167., 183.,
#          199., 215., 231., 247., 263., 279., 295., 311., 327., 343., 359.,
#          375., 391., 407., 423., 439., 455., 471., 487.],
#         [ 23.,  39.,  55.,  71.,  87., 103., 119., 135., 151., 167., 183.,
#          199., 215., 231., 247., 263., 279., 295., 311., 327., 343., 359.,
#          375., 391., 407., 423., 439., 455., 471., 487.],
#         [ 23.,  39.,  55.,  71.,  87., 103., 119., 135., 151., 167., 183.,
# ...
